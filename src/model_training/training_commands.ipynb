# %%
# Clone the repository (Replace 'your-username' with your actual GitHub username)
# !git clone https://github.com/mihaicristianfarcas/Fact-Checking-Agent-LLionelMessi.git /content/project

# Navigate into the project folder
# %cd /content/project

# Switch to model training branch
# !git checkout andrei
# !git pull

# Install all necessary python dependencies
# !pip install -r requirements.txt

# %%
# Run SFT
# !env PYTHONPATH=/content/project python -m src.model_training.train_sft --epochs 3 --max_samples 10000

# %%
# Run DPO
# !env PYTHONPATH=/content/project python -m src.model_training.train_dpo --epochs 1 --max_samples 2000

# %%
# !pytest tests/test_model_inference.py -v -s
